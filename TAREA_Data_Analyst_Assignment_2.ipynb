# %% [markdown]
# <a href="https://colab.research.google.com/github/EDSONRRs/DIPLOMADO/blob/main/TAREA_Data_Analyst_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Analyst Assignment

# %%
import pandas as pd
df_1 = pd.read_excel('/content/Assignment_2.xlsx')
df_1
# Out:
#       Employee_ID SVP Leader                          Business Title  \
# 0               1   Leader 1     Senior Commercial Account Executive
# 1               2   Leader 1     Senior Commercial Account Executive
# 2               3   Leader 1     Senior Commercial Account Executive
# 3               4   Leader 2  Enterprise Corporate Account Executive
# 4               5   Leader 1     Senior Commercial Account Executive
# ...           ...        ...                                     ...
# 2527         2528   Leader 5                       Contingent Worker
# 2528         2529   Leader 5                       Contingent Worker
# 2529         2530   Leader 5                       Contingent Worker
# 2530         2531   Leader 5                       Contingent Worker
# 2531         2532   Leader 5                       Contingent Worker
#
#                   Cost Center Cost Center Family  Length of service  \
# 0           532 Commercial AE         Commercial                 20
# ...

# %%
df_2 = pd.read_excel('/content/Assignment_2.xlsx', sheet_name = 'Completed_Trainings')
df_2
# Out:
#       Employee_ID              Training_Completed
# 0             2.0             Sell More Suite SKU
# 1             5.0             Sell More Suite SKU
# 2             9.0             Sell More Suite SKU
# 3            10.0             Sell More Suite SKU
# 4            12.0             Sell More Suite SKU
# ...           ...                             ...
# 1977          NaN  Suite/Automation Technical Lab
# 1978          NaN  Suite/Automation Technical Lab
# 1979       2436.0  Suite/Automation Technical Lab
# 1980       1876.0  Suite/Automation Technical Lab
# 1981          1.0  Suite/Automation Technical Lab
#
# [1982 rows x 2 columns]

# %%
df_3 = pd.read_excel('/content/Assignment_2.xlsx', sheet_name = 'Performance Data')
df_3
# Out:
#      Employee_ID  Opportunity ID          Type Stage 2+ Date  \
# 0          963.0           10000  New Business    2016-10-16
# 1          435.0           10005     Expansion    2017-12-14
# 2           33.0           10010     Expansion    2017-12-17
# 3         1634.0           10015     Expansion    2017-12-15
# 4         1998.0           10020  New Business    2017-12-22
# ..           ...             ...           ...           ...
# 602       1741.0           12970     Expansion    2018-01-16
# 603       1389.0           12975     Expansion    2017-12-26
# 604       1389.0           12975     Expansion    2017-12-26
# 605       1389.0           12975     Expansion    2017-12-26
# 606         16.0           12980     Expansion    2017-12-09
#
#                     Stage Close Date Product Rate Plan Charge  \
# 0    03 - Solution Review 2018-06-03       Suite Subscription
# 1          02 - Discovery 2018-03-02       Suite Subscription
# ...

# %%
df2=df_2.dropna(subset=['Employee_ID'])
df2
# Out:
#       Employee_ID              Training_Completed
# 0             2.0             Sell More Suite SKU
# 1             5.0             Sell More Suite SKU
# 2             9.0             Sell More Suite SKU
# 3            10.0             Sell More Suite SKU
# 4            12.0             Sell More Suite SKU
# ...           ...                             ...
# 1777       2482.0             Sell More Suite SKU
# 1778       2483.0             Sell More Suite SKU
# 1979       2436.0  Suite/Automation Technical Lab
# 1980       1876.0  Suite/Automation Technical Lab
# 1981          1.0  Suite/Automation Technical Lab
#
# [1782 rows x 2 columns]

# %%
DF=df_1.merge(df2, on = ['Employee_ID'])
DF
# Out:
#       Employee_ID SVP Leader                           Business Title  \
# 0               1   Leader 1      Senior Commercial Account Executive
# 1               2   Leader 1      Senior Commercial Account Executive
# 2               5   Leader 1      Senior Commercial Account Executive
# 3               9   Leader 1             Commercial Account Executive
# 4              10   Leader 1             Enterprise Account Executive
# ...           ...        ...                                      ...
# 1777         2476  Leader 11  Enterprise Pool Sales Account Executive
# 1778         2478   Leader 5                 Premier Support Engineer
# 1779         2481  Leader 11  Enterprise Pool Sales Account Executive
# 1780         2482  Leader 11  Enterprise Pool Sales Account Executive
# 1781         2483  Leader 11  Enterprise Pool Sales Account Executive
#
#                Cost Center Cost Center Family  Length of service Leave Status  \
# ...

# %%
#Elijo todos los elementos de Cost Center familiy que no sean PreSale ni Services
Emp=DF[DF['Cost Center Family'].isin (['Commercial', 'Enterprise', 'SMB', 'Mid-Market', 'Renewals', 'Ops/Strat/Eff', 'XDR', 'Transformational',
       'Advocacy', 'Partners', 'Success', 'Sales Management'] )]
#Escojo todos cuyos cursos no sean los 2 cursos obligatorios para PreSales y Services
Emple=(Emp[Emp['Training_Completed']=='Sell More Suite SKU'])

# %%
Emple['SVP Leader'].unique()
# Out:
# array(['Leader 1', 'Leader 4', 'Leader 3', 'Leader 5', 'Leader 7',
#        'Leader 10', 'Leader 9', 'Leader 11', 'Leader 2', 'Leader 12',
#        'Leader 14', 'Leader 6'], dtype=object)

# %%
#Selecciono solo los del Lider 1
Emple[Emple['SVP Leader']=='Leader 1']
L1_1=len(Emple[Emple['SVP Leader']=='Leader 1'])#obetengo cuantos hay en total de esta Dataframe
L1_1
# Out:
# 77

# %%
#Hago el mismo procedimiento para L2
Emple[Emple['SVP Leader']=='Leader 2']
L2_1=len(Emple[Emple['SVP Leader']=='Leader 2'])#obetengo cuantos hay en total de esta Dataframe
L2_1
# Out:
# 17

# %%
#Hago el mismo procedimiento para L3
Emple[Emple['SVP Leader']=='Leader 3']
L3_1=len(Emple[Emple['SVP Leader']=='Leader 3'])#obetengo cuantos hay en total de esta Dataframe
L3_1
# Out:
# 114

# %%
#Hago el mismo procedimiento para L4
Emple[Emple['SVP Leader']=='Leader 4']
L4_1=len(Emple[Emple['SVP Leader']=='Leader 4'])#obetengo cuantos hay en total de esta Dataframe
L4_1
# Out:
# 108

# %%
#Hago el mismo procedimiento para L5
Emple[Emple['SVP Leader']=='Leader 5']
L5_1=len(Emple[Emple['SVP Leader']=='Leader 5'])#obetengo cuantos hay en total de esta Dataframe
L5_1
# Out:
# 101

# %%
#Hago el mismo procedimiento para L6
Emple[Emple['SVP Leader']=='Leader 6']
L6_1=len(Emple[Emple['SVP Leader']=='Leader 6'])#obetengo cuantos hay en total de esta Dataframe
L6_1
# Out:
# 4

# %%
#Hago el mismo procedimiento para L7
Emple[Emple['SVP Leader']=='Leader 7']
L7_1=len(Emple[Emple['SVP Leader']=='Leader 7'])#obetengo cuantos hay en total de esta Dataframe
L7_1
# Out:
# 21

# %%
#Hago el mismo procedimiento para L9
Emple[Emple['SVP Leader']=='Leader 9']
L9_1=len(Emple[Emple['SVP Leader']=='Leader 9'])#obetengo cuantos hay en total de esta Dataframe
L9_1
# Out:
# 15

# %%
#Hago el mismo procedimiento para L10
Emple[Emple['SVP Leader']=='Leader 10']
L10_1=len(Emple[Emple['SVP Leader']=='Leader 10'])#obetengo cuantos hay en total de esta Dataframe
L10_1
# Out:
# 140

# %%
#Hago el mismo procedimiento para L11
Emple[Emple['SVP Leader']=='Leader 11']
L11_1=len(Emple[Emple['SVP Leader']=='Leader 11'])#obetengo cuantos hay en total de esta Dataframe
L11_1
# Out:
# 44

# %%
#Hago el mismo procedimiento para L12
Emple[Emple['SVP Leader']=='Leader 12']
L12_1=len(Emple[Emple['SVP Leader']=='Leader 12'])#obetengo cuantos hay en total de esta Dataframe
L12_1
# Out:
# 23

# %%
#Hago el mismo procedimiento para L14
Emple[Emple['SVP Leader']=='Leader 14']
L14_1=len(Emple[Emple['SVP Leader']=='Leader 14'])#obetengo cuantos hay en total de esta Dataframe
L14_1
# Out:
# 10

# %%
DFF=DF[DF['Training_Completed']=='Sell More Suite SKU']
DFF[DFF['Cost Center']=='Advocacy']#NO hay mienbros de Advocacy que tengan el curso de SKU
# Out:
# Empty DataFrame
# Columns: [Employee_ID, SVP Leader, Business Title, Cost Center, Cost Center Family, Length of service, Leave Status, is People Manager?, Region, Manager IC Helper, Training_Completed]
# Index: []

# %%
DF1=DF[DF['Leave Status']=='Active']
#DF_1=DF1[DF1['Cost Center Family']=='Advocacy'] No se filtra porque no hay ninguno
DF_1= DF1[DF1['Training_Completed'].isin(['Suite/Automation Technical Lab', 'Advanced Suite Bots Lab Course'])]
#La funcion de arriba filtra los cursos de Suit/... y Advanced....

# %%
len(df_1[df_1['Leave Status']=='Active'])#Cantidad total de empleados activos
# Out:
# 2433

# %%
DF1

# %%
#Del dataFrame anterior ahora le filtramos PreSales y Services
Df1=DF_1[DF_1['Cost Center Family'].isin(['PreSales','Services'])]
Df1
# Out:
#       Employee_ID SVP Leader                         Business Title  \
# 38             82   Leader 9  Senior Principal Solutions Consultant
# 39             82   Leader 9  Senior Principal Solutions Consultant
# 51             98   Leader 9              Senior Platform Architect
# 52             98   Leader 9              Senior Platform Architect
# 53             99   Leader 9            Senior Solutions Consultant
# ...           ...        ...                                    ...
# 1751         2437   Leader 5            Managed Services Consultant
# 1769         2468   Leader 5  Manager, Technical Account Management
# 1770         2468   Leader 5  Manager, Technical Account Management
# 1772         2471   Leader 9          Principal Solution Consultant
# 1773         2471   Leader 9          Principal Solution Consultant
#
#                           Cost Center Cost Center Family  Length of service  \
# ...

# %%
Df1['SVP Leader'].unique()#Cuantos leader tenemos
# Out:
# array(['Leader 9', 'Leader 5', 'Leader 2'], dtype=object)

# %%
Df1[Df1['SVP Leader']=='Leader 9']#Filtramos las filas que contengan a Leader 9
# Out:
#       Employee_ID SVP Leader                         Business Title  \
# 38             82   Leader 9  Senior Principal Solutions Consultant
# 39             82   Leader 9  Senior Principal Solutions Consultant
# 51             98   Leader 9              Senior Platform Architect
# 52             98   Leader 9              Senior Platform Architect
# 53             99   Leader 9            Senior Solutions Consultant
# ...           ...        ...                                    ...
# 1682         2289   Leader 9          Manager, Solutions Consulting
# 1739         2414   Leader 9         Associate Solutions Consultant
# 1740         2414   Leader 9         Associate Solutions Consultant
# 1772         2471   Leader 9          Principal Solution Consultant
# 1773         2471   Leader 9          Principal Solution Consultant
#
#                           Cost Center Cost Center Family  Length of service  \
# ...

# %%
L9_2=len(Df1[Df1['SVP Leader']=='Leader 9'])#medimos cuantos elementos tenemos en esa DataFrame
L9_2
# Out:
# 314

# %%
Df1[Df1['SVP Leader']=='Leader 5']#Filtramos las filas que contengan a Leader 5

# %%
L5_2=len(Df1[Df1['SVP Leader']=='Leader 5'])#medimos cuantos elementos tenemos en esa DataFrame
L5_2
# Out:
# 461

# %%
Df1[Df1['SVP Leader']=='Leader 2']#Filtramos las filas que contengan a Leader 2

# %%
L2_2=len(Df1[Df1['SVP Leader']=='Leader 2'])#medimos cuantos elementos tenemos en esa DataFrame
L2_2
# Out:
# 1

# %%
Emple['SVP Leader'].unique()
# Out:
# array(['Leader 1', 'Leader 4', 'Leader 3', 'Leader 5', 'Leader 7',
#        'Leader 10', 'Leader 9', 'Leader 11', 'Leader 2', 'Leader 12',
#        'Leader 14', 'Leader 6'], dtype=object)

# %%
Df1['SVP Leader'].unique()
# Out:
# array(['Leader 9', 'Leader 5', 'Leader 2'], dtype=object)

# %%
print('Respuesta 1: Tasa de finalizacion de cursos poe Leader')

# %%
#Sumamos la cantidad de Leader n de cada DataFrame para obetener la tasa de finalizacion de cursos
Leader1=(L1_1*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 1:',Leader1, '%')
# Out:
# Tasa leader 1: 3.1648170982326347 %

# %%
Leader2=((L2_1+L2_2)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 2:',Leader2, '%')
# Out:
# Tasa leader 2: 0.7398273736128237 %

# %%
Leader3=((L3_1)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 3:',Leader3, '%')
# Out:
# Tasa leader 3: 4.68557336621455 %

# %%
Leader4=((L4_1)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 4:',Leader4, '%')
# Out:
# Tasa leader 4: 4.438964241676942 %

# %%
Leader5=((L5_1+L5_2)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 5:',Leader5, '%')
# Out:
# Tasa leader 5: 23.099054665022607 %

# %%
Leader6=((L6_1)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 6:',Leader6, '%')
# Out:
# Tasa leader 6: 0.16440608302507193 %

# %%
Leader7=((L7_1)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 7:',Leader7, '%')
# Out:
# Tasa leader 7: 0.8631319358816276 %

# %%
Leader9=((L9_1+L9_2)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 9:',Leader9, '%')
# Out:
# Tasa leader 9: 13.522400328812166 %

# %%
Leader10=((L10_1)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 10:',Leader10, '%')
# Out:
# Tasa leader 10: 5.754212905877518 %

# %%
Leader11=((L11_1)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 11:',Leader11, '%')
# Out:
# Tasa leader 11: 1.8084669132757911 %

# %%
Leader12=((L12_1)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 12:',Leader12, '%')
# Out:
# Tasa leader 12: 0.9453349773941636 %

# %%
Leader14=((L14_1)*100)/2433#hacemos regla de 3 dn base a 2433 que son el total de empleados Activos
print('Tasa leader 14:',Leader14, '%')
# Out:
# Tasa leader 14: 0.41101520756267984 %

# %% [markdown]
# ## Data Challenge
#
# Sales leadership has tasked you with analyzing the data to discover how employee training
# impacts sales performance and effectiveness. The goal is to identify patterns and provide
# actionable recommendations that drive sales growth and improve team performance by
# answering the following questions.
# Questions
# 1. What is the training completion rate for each course by segments (SVP Leader/Region),
# factoring in the following caveats? Training is required for all employees except:
# * Employees currently on leave are exempt from the training requirement.
# * 'Sell More Suite SKU' course is not required for employees within the 'Advocacy'
# cost center family.
# * “Suite/Automation Technical Lab” and “Advanced Suite Bots Lab Course”
# courses are required only for employees in the 'PreSales' and 'Services' cost
# center family.
#
# 2. How would you analyze the performance of an account executive? Is there a difference
# between those who have completed training and those who have not? How would you
# segment the data and present your findings to senior stakeholders?
# * Hint: Look at this from an overall employee perspective who has completed any
# training vs. those who have not completed any training. Any training would count,
#
# rather than distinguishing which specific courses were completed, as they all
# contribute to one Suite product.
#
# 3. Any other interesting insights that you can see in the data? Any data quality issues with
# the data? Any challenges with analyzing the data? What additional data do you think
# would be useful for further analyzing the existing datasets?
#
#
#
# ---

# %%
print('Pregunta 3:')
# Out:
# Pregunta 3:

# %% [markdown]
# Seria interesante analisar que pasa con el restos de Leader, que tipo de cursos estan realizando que no son acordes a sus areas, y si esto les afecta monetariamente de buena o mala manera.El tiempo que llevan trabajando en la empresa podria ser utili para saber si ya deberian haber concluido ciertos cursos o si es proporcional al salario de otras personas que tengan el mismo tiempo de antiguedad.

# %% [markdown]
# ## Data Dictionary
#
# ### Table 1 : Employee Information
#
# This table maintains critical employment details for organization members, including
# identification, job titles, management hierarchies, tenure, and work region
#
# * **Employee_ID:** Unique identifier for each employee.
# * **SVP Leader:** Leader overseeing the employee.
# * **Business Title:** Official job title of the employee.
# * **Cost Center:** Identifier for the employee's department or unit for cost tracking.
# * **Cost Center Family:** Group of related cost centers for financial reporting.
# * **Length of Service:** Total time the employee has worked at the company.
# * **Leave Status:** Indication of whether the employee is on leave.
# * **Is People Manager?:** Indicates if the employee oversees other staff.
# * **Region:** Geographic area where the employee works.
# * **Manager IC Helper:** Additional data supporting managerial status.
# * **IC:** Individual Contributor
#
# ### Table 2: Completed Trainings
# This table records the professional development activities of employees by linking completed
# training programs to their unique identifiers
# * **Employee_ID:** Unique identifier linked to an employee who completed the training.
# * **Training Name:** Name of the training program or course that the employee completed.
#
# ### Table 3: Performance Data
# This table includes the sales and revenue generation activities of employees by cataloguing
# opportunities, their progression, and financial outcomes. It captures granular data on sales
# stage milestones, product-related charges, and revenue figures, all linked by employee and
# opportunity identifiers, making it a vital asset for analyzing sales performance and compensation
# metrics.
#
# * **Employee_ID:** Unique identifier for the employee associated.
# * **Opportunity ID:** Unique identifier for the sales opportunity.
# * **Type:** The category or classification of the opportunity.
# * Expansion is for existing business
#
# * **Stage 2+ Date:** The date when the opportunity reached or surpassed stage 2 in the
# sales process.
# * **Stage:** Current stage of the opportunity in the sales pipeline.
#  * 02 - Discovery: Initial stage where potential needs and opportunities are
# identified with the client.
#  * 03 - Solution Review: Potential solutions are presented and reviewed with the
# client.
#  * 04 - Solution Validation: Client feedback is incorporated, and solutions are
# refined and validated.
#  * 05 - Contracting / Verba: Terms are negotiated and a verbal agreement may be
# reached.
#  * 06 - Signed/07 - Closed: Formal agreement is executed with signatures from all
# parties. Signed and Closed are counted as finalized
# * **Close Date:** The date when the opportunity was closed.
# * **Product Rate Plan Charge:** The charge associated with the product's rate plan.
# * **Product Name:** The name of the product related to the opportunity.
# * **Add-On ARR (converted):** The value of the additional ARR from add-ons,
# * **Total Commissionable ARR (converted):** The total annual recurring revenue that is
# eligible for commission
